# %%
import requests
import matplotlib.pyplot as plt

# %%
endpoint = 'https://data.nashville.gov/resource/fuaa-r5cm.json?year=2016'
response = requests.get(endpoint)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '[{"month_name":"January","year":"2016","query_count":"10","query_text":"Email"}\n,{"month_name":"January","year":"2016","query_count":"13","query_text":"property"}\n,{"month_name":"January","year":"2016","query_count":"7","query_text":"waste management"}\n,{"month_name":"January","year":"2016","query_count":"21","query_text":"google"}\n,{"month_name":"January","year":"2016","query_count":"7","query_text":"pension"}\n,{"month_name":"January","year":"2016","query_count":"7","query_text":"Parking"}\n,{"month_name":"January","year":"2016","query_count":"7","query_text":"metro employee discounts"}\n,{"month_name":"January","year":"2016","query_count":"8","query_text":"tree recycling"}\n,{"month_name":"January","year":"2016","query_count":"35","query_text":"animal control"}\n,{"month_name":"January","year":"2016","query_count":"12","query_text":"Public records"}\n,{"month_name":"January","year":"2016","query_count":"10","query_text":"Mai Gooch"}\n,{"month_name":"January","year":"2016","qu
# ...

# %%
import json

# %%
res = response.json()
res
# Out:
# [{'month_name': 'January',
#   'year': '2016',
#   'query_count': '10',
#   'query_text': 'Email'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '13',
#   'query_text': 'property'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '7',
#   'query_text': 'waste management'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '21',
#   'query_text': 'google'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '7',
#   'query_text': 'pension'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '7',
#   'query_text': 'Parking'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '7',
#   'query_text': 'metro employee discounts'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '8',
#   'query_text': 'tree recycling'},
#  {'month_name': 'January',
#   'year': '2016',
#   'query_count': '35',
#   'query_text': 'animal control'},
#  {'month_name': 'January',
# ...

# %%
### 1. Make an API request that returns the months where "fire" was searched in 2016. Which month had the most searches?

# %%
endpoint ='https://data.nashville.gov/resource/fuaa-r5cm.json?year=2016'
params = {
    'query_text' : 'fire'
}
response = requests.get(endpoint, params=params)
response.text
# Out:
# '[{"month_name":"January","year":"2016","query_count":"19","query_text":"fire"}\n,{"month_name":"February","year":"2016","query_count":"35","query_text":"fire"}\n,{"month_name":"March","year":"2016","query_count":"32","query_text":"fire"}\n,{"month_name":"April","year":"2016","query_count":"26","query_text":"fire"}\n,{"month_name":"May","year":"2016","query_count":"24","query_text":"fire"}\n,{"month_name":"June","year":"2016","query_count":"31","query_text":"fire"}\n,{"month_name":"July","year":"2016","query_count":"24","query_text":"fire"}\n,{"month_name":"August","year":"2016","query_count":"47","query_text":"fire"}\n,{"month_name":"September","year":"2016","query_count":"36","query_text":"fire"}\n,{"month_name":"October","year":"2016","query_count":"38","query_text":"fire"}\n,{"month_name":"November","year":"2016","query_count":"32","query_text":"fire"}\n,{"month_name":"December","year":"2016","query_count":"38","query_text":"fire"}]\n'

# %%
import pandas as pd

# %%
data=pd.DataFrame(response.json())
data
# Out:
#    month_name  year query_count query_text
# 0     January  2016          19       fire
# 1    February  2016          35       fire
# 2       March  2016          32       fire
# 3       April  2016          26       fire
# 4         May  2016          24       fire
# 5        June  2016          31       fire
# 6        July  2016          24       fire
# 7      August  2016          47       fire
# 8   September  2016          36       fire
# 9     October  2016          38       fire
# 10   November  2016          32       fire
# 11   December  2016          38       fire

# %%
data.sort_values('query_count', ascending = False).head(1)
# Out:
#   month_name  year query_count query_text
# 7     August  2016          47       fire

# %%
### 2. Make an API request that returns all the times a query was run more than 100 times in a month. How many times did this occur?

# %%
endpoint1 ='https://data.nashville.gov/resource/fuaa-r5cm.json?$where=query_count>=100'
response = requests.get(endpoint1)

# %%
response
# Out:
# <Response [200]>

# %%
query_count = pd.DataFrame(response.json())
len(query_count)
# Out:
# 1000

# %%
res[3]
# Out:
# {'month_name': 'January',
#  'year': '2016',
#  'query_count': '21',
#  'query_text': 'google'}

# %%
### 3. Make another API request that returns all the times "codes" was searched more than 100 times in a month. 
### How many times did this occur?

# %%
endpoint2 ='https://data.nashville.gov/resource/fuaa-r5cm.json?$where=query_count>100'
params = {
    
    'query_text': 'codes' 
       
}
response2 = requests.get(endpoint2, params = params)
response2
# Out:
# <Response [200]>

# %%
response2.text
# Out:
# '[{"month_name":"September","year":"2015","query_count":"101","query_text":"codes"}\n,{"month_name":"April","month":"4","year":"2021","query_count":"102","query_text":"codes"}\n,{"month_name":"August","year":"2016","query_count":"104","query_text":"codes"}\n,{"month_name":"November","month":"11","year":"2020","query_count":"104","query_text":"codes"}\n,{"month_name":"December","year":"2017","query_count":"106","query_text":"codes"}\n,{"month_name":"May","year":"2016","query_count":"107","query_text":"codes"}\n,{"month_name":"April","year":"2016","query_count":"111","query_text":"codes"}\n,{"month_name":"July","month":"7","year":"2021","query_count":"114","query_text":"codes"}\n,{"month_name":"January","year":"2017","query_count":"115","query_text":"codes"}\n,{"month_name":"May","month":"5","year":"2021","query_count":"115","query_text":"codes"}\n,{"month_name":"August","year":"2015","query_count":"117","query_text":"codes"}\n,{"month_name":"February","year":"2016","query_count":"121"
# ...

# %%
codes_data = pd.DataFrame(response2.json())
codes_data
# Out:
#    month_name  year query_count query_text month
# 0   September  2015         101      codes   NaN
# 1       April  2021         102      codes     4
# 2      August  2016         104      codes   NaN
# 3    November  2020         104      codes    11
# 4    December  2017         106      codes   NaN
# 5         May  2016         107      codes   NaN
# 6       April  2016         111      codes   NaN
# 7        July  2021         114      codes     7
# 8     January  2017         115      codes   NaN
# 9         May  2021         115      codes     5
# 10     August  2015         117      codes   NaN
# 11   February  2016         121      codes   NaN
# 12   February  2019         124      codes     2
# 13       June  2019         125      codes     6
# 14  September  2019         126      codes     9
# 15    January  2019         129      codes     1
# 16  September  2020         130      codes     9
# 17   February  2021         131      codes     2
# ...

# %%
len(codes_data)
# Out:
# 56

# %%
### 4. Make an API request that returns the entire Top 500 Monthly Searches dataset. 
### Make a chart that shows the number of times "maps" was searched in a month across the entire time frame.

# %%
endpoint3 ='https://data.nashville.gov/resource/fuaa-r5cm.json?$where=query_count=500'
response = requests.get(endpoint3, params=params)

# %%
response
# Out:
# <Response [200]>
